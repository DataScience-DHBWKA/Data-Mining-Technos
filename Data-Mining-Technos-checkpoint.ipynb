# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import seaborn as sns # Plots
import matplotlib.pyplot as plt # Plots

# %%
train_data = pd.read_csv("C:\\Users\\ann-f\\Documents\\mymoviedb.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 train_data = pd.read_csv("C:\\Users\\ann-f\\Documents\\mymoviedb.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
chunksize = 10 ** 6 # adjust this value depending on your system's memory
for chunk in pd.read_csv("C:\\Users\\ann-f\\Documents\\mymoviedb.csv", chunksize=chunksize):
    process(chunk) # replace this with your processing function
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[26], line 2
#       1 chunksize = 10 ** 6 # adjust this value depending on your system's memory
# ----> 2 for chunk in pd.read_csv("C:\\Users\\ann-f\\Documents\\mymoviedb.csv", chunksize=chunksize):
#       3     process(chunk)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1624, in TextFileReader.__next__(self)
#    1622 def __next__(self) -> DataFrame:
#    1623     try:
# -> 1624         return self.get_chunk()
#    1625     except StopIteration:
#    1626         self.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1733, in TextFileReader.get_chunk(self, size)
#    1731         raise StopIteration
#    1732     size = min(size, self.nrows - self._currow)
# -> 1733 return self.read(nrows=size)
#
# ...

# %%
pd.read_csv("C:\\Users\\ann-f\\Documents\\mymoviedb.csv", engine='python')
# Out:
#      Release_Date                                 Title  \
# 0      2021-12-15               Spider-Man: No Way Home
# 1      2022-03-01                            The Batman
# 2      2022-02-25                               No Exit
# 3      2021-11-24                               Encanto
# 4      2021-12-22                        The King's Man
# ...           ...                                   ...
# 9832   1973-10-15                              Badlands
# 9833   2020-10-01                      Violent Delights
# 9834   2016-05-06                          The Offering
# 9835   2021-03-31  The United States vs. Billie Holiday
# 9836   1984-09-23                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
train_data.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 train_data.shape
#
# NameError: name 'train_data' is not defined
